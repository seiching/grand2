# %%
#type1 依斷字後符合apart cut及cpart 的數目選高的當答案,如果,完全不符合,就用猜的
#type2 依斷字後符合apart cut及cpart 的數目選低的當答案
import sqlite3
import pandas as pd
import random
import os
import sys
import csv
import spiltc
import jieba
jieba.set_dictionary('jieba_dict/dict.txt.big')

def genbtype(conn):
    try:        
        sql="update Bpart set Qtype=1"  
        conn.execute(sql )
    except Exception as e:
        print("Failed update Qtype 1 : "+ str(e)) 
    conn.commit()
    sql="update Bpart set Qtype=2 WHERE sentence like '%非%' and sentence not like '%非常%' or sentence like '%不包%' or sentence like '%不是%' or  sentence like '%不屬%' "  
    try:        
        conn.execute(sql )
    except Exception as e:
        print("Failed update qtype 2: "+ str(e)) 
    conn.commit()
 
    print("Qtype1 positive, qtype2 negative over")
#產生答案
def gencsv(conn):
    try:
        sql="SELECT  ID,  Answer FROM Cpart order by ID;"
        pdgrand=pd.read_sql(sql,conn)
        print('total answer no=',len(pdgrand))
        pdgrand.to_csv(r'./answer.csv',columns=['ID','Answer'],index=False,sep=',')
        conn.commit()
    except Exception as e:
        print('gencsv error'+str(e))
#產生答案
def genscore(conn):
    try:
        sql="SELECT ID, COALESCE( score1,0) as score1, COALESCE(score2,0) as score2,\
        COALESCE(score3,0) as score3 , COALESCE(score4,0) as score4 FROM Cpart ; "
        pdgrand=pd.read_sql(sql,conn)
        print('score no=',len(pdgrand))
        pdgrand.to_csv(r'./score.csv',columns=['ID','score1','score2','score3','score4'],index=False,sep=',')
        conn.commit()
    except Exception as e:
        print('genscore err'+str(e))
def addpatch(conn):
##################################
#check 合併後少的檔案
##################################
  
  #蒐集目錄下wav檔名單

    try:
        wavlist = []
        directory = 'A/' 
        objects = os.listdir(directory)
        for filelist in objects:
            if filelist.find('.wav') != -1:
                filelist='C'+filelist[1:]
                wavlist.append(filelist.upper())
        print('afgterfilelist')
        wavlist_set=set(wavlist)

  #取得DB中的已辨識名單

        cursor = conn.cursor()
        sql="SELECT Filename from  Cpart  ;" 
        cursor.execute(sql)
        dbvalues = list(cursor.fetchall())
        ldbvalues=[]
        sdbvalues=set()
        for i in dbvalues:
            ldbvalues.append(i[0])
            sdbvalues=set(ldbvalues)

        #比較目錄名單及DB名單的差異
        diff=wavlist_set-sdbvalues

        #開啟新DB，將缺少的名單存入
        print('add patch from A folder'+str(len(diff)))
        for filename in diff:
            try:
                ID=int(filename[4:8])
                sql="insert into Cpart (filename,ID) VALUES('%s',%d)"  %(filename,ID)
                #print(sql)
                conn.execute(sql)
            except Exception as e:
                print("Failed insert db: "+ str(e)) 
                print(sql)
        
        conn.commit() 
    except Exception as e:
        print('addpatch err'+str(e))
   
#answettype =0 表示答案預設0,否則用random
def initanswer(conn,answertype):
    try:
        sql="select * from Cpart"
        pdgrand=pd.read_sql(sql,conn)
        answer=0
        for i in range(len(pdgrand)):
            filename=pdgrand.filename.values[i]
            if answertype!=0:
                answer=random.randint(1,4)   
            sql="update Cpart set Answer=%d where filename='%s'; " %(answer,filename)
            #print(sql)
            conn.execute(sql )
        conn.commit()
    except Exception as e:
        print('init answer err'+str(e))

def gentype2score(conn):
    try:
        sql="SELECT C.ID,c.qno as qno,count(*) as score \
            FROM Ccut c, acut a,bpart b where a.id=c.id and a.cut=c.cut and a.id=b.id \
            and b.Qtype= 2 group by c.ID,qno order by c.ID,count(*) DESC"     
        pdgrand=pd.read_sql(sql,conn)
        
        for i in range(len(pdgrand)):
            ID=pdgrand.ID.values[i]
            qno=pdgrand.qno.values[i]
            score=-pdgrand.score.values[i] 
            sql="update Cpart set score%d=%d where ID =%d " %(qno,score,ID)
            conn.execute(sql)
        conn.commit()
    except Exception as e:
        print('gentype2score err '+str(e))
      #print(sql)
    
        
def gentype2ans(conn):
  try:  
    gentype2score(conn)
    sql='SELECT c.ID, COALESCE(score1,0)score1, COALESCE(score2,0)score2,\
      COALESCE(score3,0)score3, COALESCE(score4,0)score4 FROM Cpart c,\
      Bpart B where c.id=b.id and qtype=2;'
    pdgrand=pd.read_sql(sql,conn)

    for i in range(len(pdgrand)):
      ID=pdgrand.ID.values[i]
      score1=pdgrand.score1.values[i] 
      score2=pdgrand.score2.values[i] 
      score3=pdgrand.score3.values[i] 
      score4=pdgrand.score4.values[i] 
      maxanswer=score1
      answer=1
      if score2>maxanswer:
        maxanswer=score2
        answer=2
      elif score3>maxanswer:
        maxanswer=score3
        answer=3
      elif score4>maxanswer:
        answer=4
      sql="update Cpart set Answer=%d where ID =%d " %(answer,ID)
     # print(sql)
      conn.execute(sql )
    conn.commit()
  except Exception as e:
    print("Failed gentype2ans error "+ str(e))

#正向的問題
def gentype1ans(conn):
  try:  
    sql="SELECT C.ID,c.qno as qno,count(*) as score \
      FROM Ccut c, acut a,bpart b where a.id=c.id and a.cut=c.cut and a.id=b.id \
      and b.Qtype=1 group by c.ID,qno order by c.ID,count(*) DESC "
    #print(sql)
    pdgrand=pd.read_sql(sql,conn)
    oldID=0
    for i in range(len(pdgrand)):
      ID=pdgrand.ID.values[i]
      qno=pdgrand.qno.values[i]
      score=pdgrand.score.values[i] 
      sql="update Cpart set score%d=%d where ID =%d " %(qno,score,ID)
      #print(sql)
      conn.execute(sql )
      #sql="update list_A set Answer=%d where substr(filename,5,4) ='%s' " %(qno,filename[5:4])
      if ID!=oldID:
        sql="update Cpart set Answer=%d where ID =%d " %(qno,ID)
      #print(sql)
        conn.execute(sql )
        oldID=ID
    conn.commit()
  except Exception as e:
    print("Failed gentype2ans error "+ str(e))
    
def cutab(conn,part,cutmethod):
    try:
        sql="delete FROM %scut;" %(part)
        #print(sql)
        conn.execute(sql )
        conn.commit()
    except Exception as e:
        print('delete error'+ str(e))
    try:
        sql="SELECT ID, sentence FROM %spart;" %(part)
        pdgrand=pd.read_sql(sql,conn)
        for i in range(len(pdgrand)):
            ID=pdgrand.ID.values[i]
            sentence=pdgrand.sentence.values[i]
            if sentence is None:
                print('none'+str(ID))
                continue
            #print(station)
            words=sentence
            if cutmethod ==1:
                words = jieba.cut(sentence, cut_all=False)
            for j in words:
                try:
                    sql="insert into %scut (ID, cut) VALUES( %d,'%s')"  %(part,ID, j)
                    # print(sql)
                    if j!=' ':
                        conn.execute(sql )
                except Exception as e:
                    print("Failed insert "+ str(e))
        conn.commit()
    except Exception as e:
                    print("Failed cut "+ str(e))
def cutcq(conn,ID,words,qno,cutmethod):
    try:
        if cutmethod ==1:
            words = jieba.cut(words, cut_all=False)
        for j in words:
            sql="insert into Ccut (ID, cut,qno) VALUES(%d, '%s',%d )"  %(ID, j,qno)
            if j!=' ':
                conn.execute(sql )
    except Exception as e:
        print('cutcq ID='+str(ID)+' no='+str(qno)+str(e))      
def cutc(conn,cutmethod):
    try:
        sql="delete FROM Ccut;" 
        print(sql)
        conn.execute(sql )
        conn.commit()
    except Exception as e:
        print('cutc error'+str(e))
    try:
        sql="SELECT ID, coalesce(sentence,''),Q1,Q2,Q3,Q4 FROM Cpart;"
        pdgrand=pd.read_sql(sql,conn)
        for i in range(len(pdgrand)):            
            ID=pdgrand.ID.values[i]
            sentence=pdgrand.Q1.values[i]
            #print('test'+sentence)
            if sentence is None:
                print('none q1 '+str(ID))
            else:
               cutcq(conn,ID,sentence,1,cutmethod)                                                              
            sentence=pdgrand.Q2.values[i]
            if sentence is None:
                print('none q2 '+str(ID))
            else:
               cutcq(conn,ID,sentence,2,cutmethod)
            sentence=pdgrand.Q3.values[i]
            if sentence is None:
                print('none q3 '+str(ID))
            else:
               cutcq(conn,ID,sentence,3,cutmethod)                                                                 
            sentence=pdgrand.Q4.values[i]
            if sentence is None:
                print('none q4 '+str(ID))
            else:
               cutcq(conn,ID,sentence,4,cutmethod)                                                                   
        conn.commit()
    except Exception as e:
        print("Failed insert Ccut: "+ str(e)) 
        print(sql)

try:    
    conn = sqlite3.connect('grandk3.db')
    cutab(conn,'A',1)
    print('cut A finish')
    cutab(conn,'B',1)
    print('cut B finish')
   # spiltc.spiltc(conn)
    print('spiltc finish')   
    cutc(conn,1)
    print('cutc fiish')  
 
    #把 cpart補到1500
    addpatch(conn)
    print('補完了')
    #1是random,0是起始為0
    initanswer(conn,0)
    print('init finish')
    genbtype(conn)
    #for bpart type1正向問題
    gentype1ans(conn)
    print('answer1 complete')
    #for bpart type2反向問題
    gentype2ans(conn)
    print('answer2 complete')
    gencsv(conn)
    print('generate CSV file')
    genscore(conn)
    print('generate score file')
    conn.commit()
    conn.close() 
except Exception as e:
    print("Failed main error "+ str(e))
# Out:
# Building prefix dict from D:\aischool\20180914\kaggle4\data\wav\jieba_dict\dict.txt.big ...
# Dumping model to file cache C:\Users\user\AppData\Local\Temp\jieba.ud17c1ee0cee454531e779e1c82891504.cache
# Loading model cost 1.903 seconds.
# Prefix dict has been built succesfully.
# cut A finish
# cut B finish
# spiltc finish
# delete FROM Ccut;
# cutc fiish
# afgterfilelist
# add patch from A folder1500
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000537.WAV',537)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000828.WAV',828)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001483.WAV',1483)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000471.WAV',471)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000364.WAV',364)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001198.WAV',1198)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000452.WAV',452)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000264.WAV',264)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000243.WAV',243)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000136.WAV',136)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000433.WAV',433)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000314.WAV',314)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000316.WAV',316)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000545.WAV',545)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001455.WAV',1455)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001112.WAV',1112)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001337.WAV',1337)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001262.WAV',1262)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000240.WAV',240)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000320.WAV',320)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000275.WAV',275)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000032.WAV',32)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001293.WAV',1293)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000345.WAV',345)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000071.WAV',71)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000529.WAV',529)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001298.WAV',1298)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001211.WAV',1211)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001424.WAV',1424)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001376.WAV',1376)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001387.WAV',1387)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000333.WAV',333)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000482.WAV',482)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000208.WAV',208)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000405.WAV',405)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000258.WAV',258)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000124.WAV',124)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001046.WAV',1046)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001278.WAV',1278)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001404.WAV',1404)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001064.WAV',1064)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000449.WAV',449)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000845.WAV',845)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000077.WAV',77)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000445.WAV',445)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000284.WAV',284)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000156.WAV',156)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001041.WAV',1041)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001163.WAV',1163)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000166.WAV',166)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000132.WAV',132)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001406.WAV',1406)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001180.WAV',1180)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001382.WAV',1382)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001017.WAV',1017)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000252.WAV',252)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000509.WAV',509)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000575.WAV',575)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001440.WAV',1440)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001217.WAV',1217)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000279.WAV',279)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001396.WAV',1396)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000172.WAV',172)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001001.WAV',1001)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000061.WAV',61)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001416.WAV',1416)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000326.WAV',326)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001243.WAV',1243)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001031.WAV',1031)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001463.WAV',1463)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000348.WAV',348)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001409.WAV',1409)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000304.WAV',304)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000332.WAV',332)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001072.WAV',1072)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000206.WAV',206)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000594.WAV',594)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000034.WAV',34)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000395.WAV',395)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001445.WAV',1445)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000095.WAV',95)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000396.WAV',396)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000527.WAV',527)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000427.WAV',427)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001113.WAV',1113)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000834.WAV',834)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000403.WAV',403)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001231.WAV',1231)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000468.WAV',468)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000884.WAV',884)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000044.WAV',44)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000823.WAV',823)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001352.WAV',1352)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000425.WAV',425)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000049.WAV',49)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000586.WAV',586)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000123.WAV',123)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001254.WAV',1254)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001235.WAV',1235)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000072.WAV',72)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000182.WAV',182)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001252.WAV',1252)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001331.WAV',1331)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000238.WAV',238)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000354.WAV',354)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000372.WAV',372)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000822.WAV',822)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000479.WAV',479)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000088.WAV',88)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000861.WAV',861)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000547.WAV',547)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000398.WAV',398)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001334.WAV',1334)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001405.WAV',1405)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001121.WAV',1121)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000122.WAV',122)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000888.WAV',888)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000801.WAV',801)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001435.WAV',1435)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000400.WAV',400)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000013.WAV',13)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001175.WAV',1175)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000438.WAV',438)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001373.WAV',1373)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000221.WAV',221)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000118.WAV',118)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000135.WAV',135)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001464.WAV',1464)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000889.WAV',889)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001273.WAV',1273)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000543.WAV',543)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000267.WAV',267)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000404.WAV',404)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001209.WAV',1209)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000158.WAV',158)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001007.WAV',1007)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001410.WAV',1410)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000339.WAV',339)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000896.WAV',896)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001458.WAV',1458)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000070.WAV',70)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000107.WAV',107)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001481.WAV',1481)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000078.WAV',78)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000806.WAV',806)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001448.WAV',1448)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000587.WAV',587)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001429.WAV',1429)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000289.WAV',289)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001170.WAV',1170)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001245.WAV',1245)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000460.WAV',460)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001061.WAV',1061)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000358.WAV',358)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000253.WAV',253)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000313.WAV',313)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000193.WAV',193)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000176.WAV',176)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000181.WAV',181)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000865.WAV',865)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001086.WAV',1086)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000442.WAV',442)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000157.WAV',157)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001308.WAV',1308)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000576.WAV',576)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000489.WAV',489)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001199.WAV',1199)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000083.WAV',83)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000120.WAV',120)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001359.WAV',1359)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000200.WAV',200)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000016.WAV',16)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000352.WAV',352)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001365.WAV',1365)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000108.WAV',108)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000484.WAV',484)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000580.WAV',580)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001498.WAV',1498)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000466.WAV',466)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001244.WAV',1244)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000453.WAV',453)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000578.WAV',578)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000259.WAV',259)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000146.WAV',146)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000347.WAV',347)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001274.WAV',1274)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000225.WAV',225)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000550.WAV',550)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001202.WAV',1202)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001342.WAV',1342)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000381.WAV',381)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000288.WAV',288)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000383.WAV',383)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001320.WAV',1320)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001371.WAV',1371)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000322.WAV',322)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000390.WAV',390)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001210.WAV',1210)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001184.WAV',1184)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000129.WAV',129)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000011.WAV',11)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000143.WAV',143)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001349.WAV',1349)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000315.WAV',315)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001197.WAV',1197)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001500.WAV',1500)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000821.WAV',821)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001109.WAV',1109)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001167.WAV',1167)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000904.WAV',904)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001305.WAV',1305)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001013.WAV',1013)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001131.WAV',1131)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001151.WAV',1151)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000844.WAV',844)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000081.WAV',81)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000291.WAV',291)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001276.WAV',1276)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000367.WAV',367)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001385.WAV',1385)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000480.WAV',480)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000312.WAV',312)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001434.WAV',1434)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000272.WAV',272)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000149.WAV',149)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000853.WAV',853)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001212.WAV',1212)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001343.WAV',1343)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000023.WAV',23)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000356.WAV',356)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001413.WAV',1413)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001372.WAV',1372)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000595.WAV',595)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001044.WAV',1044)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001216.WAV',1216)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000397.WAV',397)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000321.WAV',321)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000194.WAV',194)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000573.WAV',573)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001172.WAV',1172)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001234.WAV',1234)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001174.WAV',1174)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000213.WAV',213)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000201.WAV',201)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000203.WAV',203)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000300.WAV',300)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000211.WAV',211)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000113.WAV',113)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000830.WAV',830)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000233.WAV',233)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000464.WAV',464)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001344.WAV',1344)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001417.WAV',1417)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001224.WAV',1224)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000876.WAV',876)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001495.WAV',1495)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001492.WAV',1492)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000411.WAV',411)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000007.WAV',7)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000585.WAV',585)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000325.WAV',325)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000456.WAV',456)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001480.WAV',1480)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001478.WAV',1478)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000879.WAV',879)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001204.WAV',1204)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001297.WAV',1297)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000512.WAV',512)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000870.WAV',870)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000059.WAV',59)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000057.WAV',57)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000104.WAV',104)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000805.WAV',805)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000311.WAV',311)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000366.WAV',366)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000368.WAV',368)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001468.WAV',1468)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001423.WAV',1423)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000127.WAV',127)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000058.WAV',58)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001150.WAV',1150)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000548.WAV',548)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001346.WAV',1346)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000097.WAV',97)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001379.WAV',1379)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000553.WAV',553)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000268.WAV',268)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000540.WAV',540)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001340.WAV',1340)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000528.WAV',528)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000014.WAV',14)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000851.WAV',851)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000426.WAV',426)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000457.WAV',457)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001187.WAV',1187)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000174.WAV',174)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000365.WAV',365)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001011.WAV',1011)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001426.WAV',1426)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001144.WAV',1144)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000868.WAV',868)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000153.WAV',153)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000470.WAV',470)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000360.WAV',360)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000006.WAV',6)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001111.WAV',1111)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000062.WAV',62)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000257.WAV',257)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001201.WAV',1201)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000847.WAV',847)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000091.WAV',91)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000812.WAV',812)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001301.WAV',1301)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000100.WAV',100)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000863.WAV',863)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001427.WAV',1427)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000369.WAV',369)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001162.WAV',1162)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000232.WAV',232)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001237.WAV',1237)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001145.WAV',1145)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000532.WAV',532)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001286.WAV',1286)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001233.WAV',1233)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001368.WAV',1368)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001203.WAV',1203)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001364.WAV',1364)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001192.WAV',1192)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000036.WAV',36)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000110.WAV',110)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000093.WAV',93)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001027.WAV',1027)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001419.WAV',1419)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000323.WAV',323)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000020.WAV',20)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001375.WAV',1375)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001271.WAV',1271)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001189.WAV',1189)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000255.WAV',255)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001240.WAV',1240)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001119.WAV',1119)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001173.WAV',1173)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000399.WAV',399)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000572.WAV',572)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000887.WAV',887)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000189.WAV',189)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001269.WAV',1269)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000441.WAV',441)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000451.WAV',451)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001392.WAV',1392)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000492.WAV',492)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000894.WAV',894)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001335.WAV',1335)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000111.WAV',111)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000175.WAV',175)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000507.WAV',507)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000567.WAV',567)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000214.WAV',214)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000589.WAV',589)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001255.WAV',1255)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000506.WAV',506)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001358.WAV',1358)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001208.WAV',1208)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000420.WAV',420)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000128.WAV',128)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000415.WAV',415)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000882.WAV',882)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001491.WAV',1491)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000501.WAV',501)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001196.WAV',1196)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000385.WAV',385)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001118.WAV',1118)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001130.WAV',1130)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001147.WAV',1147)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000242.WAV',242)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001238.WAV',1238)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000262.WAV',262)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000826.WAV',826)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000458.WAV',458)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000295.WAV',295)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000421.WAV',421)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000895.WAV',895)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000590.WAV',590)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000363.WAV',363)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001134.WAV',1134)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000577.WAV',577)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000231.WAV',231)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001279.WAV',1279)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001205.WAV',1205)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000588.WAV',588)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001283.WAV',1283)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000803.WAV',803)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001317.WAV',1317)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000807.WAV',807)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001132.WAV',1132)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001036.WAV',1036)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000497.WAV',497)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000508.WAV',508)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000273.WAV',273)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000141.WAV',141)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000382.WAV',382)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001043.WAV',1043)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001462.WAV',1462)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001136.WAV',1136)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000298.WAV',298)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001250.WAV',1250)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001402.WAV',1402)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000486.WAV',486)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001345.WAV',1345)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000538.WAV',538)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001333.WAV',1333)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001148.WAV',1148)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000045.WAV',45)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000197.WAV',197)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000526.WAV',526)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000131.WAV',131)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001141.WAV',1141)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000487.WAV',487)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001195.WAV',1195)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000227.WAV',227)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000349.WAV',349)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001220.WAV',1220)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000455.WAV',455)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# ...
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000370.WAV',370)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000040.WAV',40)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000280.WAV',280)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000306.WAV',306)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001299.WAV',1299)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000809.WAV',809)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001328.WAV',1328)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000204.WAV',204)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000392.WAV',392)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000542.WAV',542)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000274.WAV',274)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000178.WAV',178)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000373.WAV',373)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001025.WAV',1025)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000301.WAV',301)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000119.WAV',119)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000897.WAV',897)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001430.WAV',1430)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000416.WAV',416)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000524.WAV',524)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001497.WAV',1497)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001304.WAV',1304)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001336.WAV',1336)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001038.WAV',1038)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001267.WAV',1267)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001288.WAV',1288)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000379.WAV',379)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000520.WAV',520)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000155.WAV',155)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000375.WAV',375)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000163.WAV',163)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001135.WAV',1135)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000402.WAV',402)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000051.WAV',51)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001122.WAV',1122)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001415.WAV',1415)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001193.WAV',1193)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000516.WAV',516)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001472.WAV',1472)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000488.WAV',488)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001152.WAV',1152)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000832.WAV',832)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000410.WAV',410)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001411.WAV',1411)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000444.WAV',444)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000503.WAV',503)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000495.WAV',495)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001215.WAV',1215)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001484.WAV',1484)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000115.WAV',115)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001117.WAV',1117)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001035.WAV',1035)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000079.WAV',79)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001384.WAV',1384)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000003.WAV',3)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001306.WAV',1306)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000047.WAV',47)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000299.WAV',299)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000293.WAV',293)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000170.WAV',170)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000351.WAV',351)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000555.WAV',555)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001014.WAV',1014)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000324.WAV',324)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001115.WAV',1115)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001034.WAV',1034)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001319.WAV',1319)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000087.WAV',87)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000318.WAV',318)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000025.WAV',25)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000103.WAV',103)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000130.WAV',130)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000892.WAV',892)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001078.WAV',1078)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000878.WAV',878)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000308.WAV',308)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001476.WAV',1476)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000048.WAV',48)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000344.WAV',344)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000378.WAV',378)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000514.WAV',514)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000362.WAV',362)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000010.WAV',10)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000343.WAV',343)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000534.WAV',534)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000813.WAV',813)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000374.WAV',374)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001309.WAV',1309)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000067.WAV',67)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000223.WAV',223)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001221.WAV',1221)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001026.WAV',1026)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000393.WAV',393)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000461.WAV',461)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000217.WAV',217)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001453.WAV',1453)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000116.WAV',116)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000210.WAV',210)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001157.WAV',1157)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000027.WAV',27)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001158.WAV',1158)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000033.WAV',33)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000854.WAV',854)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000839.WAV',839)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001104.WAV',1104)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000039.WAV',39)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001289.WAV',1289)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001421.WAV',1421)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000055.WAV',55)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001457.WAV',1457)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001408.WAV',1408)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000394.WAV',394)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000068.WAV',68)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000816.WAV',816)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000836.WAV',836)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001292.WAV',1292)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000541.WAV',541)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000073.WAV',73)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000271.WAV',271)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001474.WAV',1474)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000137.WAV',137)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001456.WAV',1456)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000900.WAV',900)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000842.WAV',842)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000901.WAV',901)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000454.WAV',454)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000282.WAV',282)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001137.WAV',1137)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001383.WAV',1383)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000841.WAV',841)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001488.WAV',1488)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000112.WAV',112)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000574.WAV',574)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000283.WAV',283)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000835.WAV',835)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000808.WAV',808)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000872.WAV',872)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000147.WAV',147)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000874.WAV',874)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0000184.WAV',184)
# Failed insert db: UNIQUE constraint failed: Cpart.ID
# insert into Cpart (filename,ID) VALUES('C0001222.WAV',1222)
# 補完了
# init finish
# Qtype1 positive, qtype2 negative over
# answer1 complete
# answer2 complete
# total answer no= 1840
# generate CSV file
# score no= 1840
# generate score file

# %%
import sqlite3
def genbtype(conn):
  sql="update Bpart set Qtype=1"  
  try:        
        conn.execute(sql )
  except Exception as e:
        print("Failed update Qtype 1 : "+ str(e)) 
  conn.commit()
  sql="update Bpart set Qtype=2 WHERE sentence like '%非%' and sentence not like '%非常%' or sentence like '%不包%' or sentence like '%不是%' or  sentence like '%不屬%' "  
  try:
        
        conn.execute(sql )
  except Exception as e:
        print("Failed update qtype 2: "+ str(e)) 
  conn.commit()
  conn.close()
  print("Qtype1 positive, qtype2 negative over")
# Out:
# Qtype1 positive, qtype2 negative over

# %%
conn.close()

# %%
#輸出答案
import jieba  
import sqlite3
import numpy as np
import pandas as pd
import random
conn = sqlite3.connect('grand.db')
#sql="SELECT cast(substr(filename,5,4) as int)  as ID,  Answer FROM Cpart;"
sql="SELECT cast(substr(filename,5,4) as int)  as ID,1 as Answer,filename FROM list_A order by filename"
#print(sql)
pdgrand=pd.read_sql(sql,conn)
for i in range(len(pdgrand)):
   answer=random.randint(1,4)  
   filename=pdgrand.filename.values[i]
   pdgrand.Answer.values[i]=answer
   sql="update list_A set Answer=%d where filename='%s'; " %(answer,filename)
      #print(sql)
   conn.execute(sql )
conn.commit()
conn.close()
print(len(pdgrand))

#pdgrand.to_csv(r'./answ0721sub1.csv',columns=['ID','Answer'],index=False,sep=',')
# Out:
# 1500
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-13-6e495eede123> in <module>()
#      23
#      24 #pdgrand.to_csv(r'./answ0721sub1.csv',columns=['ID','Answer'],index=False,sep=',')
# ---> 25 conn.commit()
#      26
#      27 conn.close()
#
# ProgrammingError: Cannot operate on a closed database.

# %%
#輸出答案
import jieba  
import sqlite3
import numpy as np
import pandas as pd
import random
conn = sqlite3.connect('grand.db')
def gencsv(conn):
  sql="SELECT  ID,  Answer FROM Cpart order by ID;"
  pdgrand=pd.read_sql(sql,conn)
  print(len(pdgrand))
  pdgrand.to_csv(r'./answ0721sub6.csv',columns=['ID','Answer'],index=False,sep=',')
  conn.commit()
gencsv(conn)
conn.close()
# Out:
# 1500

# %%
a=0.987654321

# %%
#起始答案
import jieba  
import sqlite3
import numpy as np
import pandas as pd
import random
conn = sqlite3.connect('grand.db')

sql="select * from Cpart"
pdgrand=pd.read_sql(sql,conn)

for i in range(len(pdgrand)):
   filename=pdgrand.filename.values[i]
   answer=random.randint(1,4)   
   print(answer)
   sql="update Cpart set Answer=%d where filename='%s'; " %(answer,filename)
      #print(sql)
   conn.execute(sql )
conn.commit()
conn.close()

# %%
#起始答案
import jieba  
import sqlite3
import numpy as np
import pandas as pd
import random
conn = sqlite3.connect('grand.db')

sql="select * from Cpart"
pdgrand=pd.read_sql(sql,conn)

for i in range(len(pdgrand)):
   filename=pdgrand.filename.values[i]
   ID=int(filename[4:8])
   #answer=random.randint(1,4)   
   #print(answer)
   sql="update Cpart set ID='%s' where filename='%s'; " %(ID,filename)
      #print(sql)
   conn.execute(sql )
conn.commit()
conn.close()
print('finish')
# Out:
# finish

# %%
a='C0000554.wav'
print(a[4:8])
print(int(a[4:8]))
# Out:
# 0554
# 554

# %%
#依斷字後符合apart cut及cpart 的數目選高的當答案,如果,完全不符合,就沒答案
import sqlite3
import pandas as pd
import random
import os
import sys
import csv

conn = sqlite3.connect('grand.db')
def genbtype(conn):
  sql="update Bpart set Qtype=1"  
  try:        
        conn.execute(sql )
  except Exception as e:
        print("Failed update Qtype 1 : "+ str(e)) 
  conn.commit()
  sql="update Bpart set Qtype=2 WHERE sentence like '%非%' and sentence not like '%非常%' or sentence like '%不包%' or sentence like '%不是%' or  sentence like '%不屬%' "  
  try:
        
        conn.execute(sql )
  except Exception as e:
        print("Failed update qtype 2: "+ str(e)) 
  conn.commit()
 
  print("Qtype1 positive, qtype2 negative over")
#產生答案
def gencsv(conn):
  sql="SELECT  ID,  Answer FROM Cpart order by ID;"
  pdgrand=pd.read_sql(sql,conn)
  print(len(pdgrand))
  pdgrand.to_csv(r'./answer.csv',columns=['ID','Answer'],index=False,sep=',')
  conn.commit()
#產生答案
def genscore(conn):
  sql="SELECT ID, COALESCE( score1,0) as score1, COALESCE(score2,0) as score2,\
  COALESCE(score3,0) as score3 , COALESCE(score4,0) as score4 FROM Cpart ; "

  pdgrand=pd.read_sql(sql,conn)
  print(len(pdgrand))
  pdgrand.to_csv(r'./score.csv',columns=['ID','score1','score2','score3','score4'],index=False,sep=',')
  conn.commit()
def addpatch(conn):
##################################
#check 合併後少的檔案
##################################

  #蒐集目錄下wav檔名單
  wavlist = []
  directory = 'C/' 
  objects = os.listdir(directory)
  for filelist in objects:
    if filelist.find('.wav') != -1:
        wavlist.append(filelist)
       # print(filelist)
    wavlist_set=set(wavlist)

  #取得DB中的已辨識名單

  cursor = conn.cursor()
  sql="SELECT filename from  Cpart  ;" 
  cursor.execute(sql)
  dbvalues = list(cursor.fetchall())
  ldbvalues=[]
  for i in dbvalues:
    ldbvalues.append(i[0])
  sdbvalues=set(ldbvalues)

  #比較目錄名單及DB名單的差異
  diff=wavlist_set-sdbvalues

  #開啟新DB，將缺少的名單存入
  for filename in diff:
    try:
        ID=int(filename[4:8])
        sql="insert into Cpart (filename,ID) VALUES('%s',%d)"  %(filename,ID)
        print(sql)
        conn.execute(sql)
    except Exception as e:
        print("Failed insert db: "+ str(e)) 
        print(sql)
  conn.commit() 
   
#answettype =0 表示答案預設0,否則用random
def initanswer(conn,answertype):
    sql="select * from Cpart"
    pdgrand=pd.read_sql(sql,conn)
    answer=0
    for i in range(len(pdgrand)):
       filename=pdgrand.filename.values[i]
       if answertype!=0:
           answer=random.randint(1,4)   
       sql="update Cpart set Answer=%d where filename='%s'; " %(answer,filename)
      #print(sql)
       conn.execute(sql )
    conn.commit()
#把 cpart補到1500
addpatch(conn)
print('補完了')
initanswer(conn,1)
print('init finish')
genbtype(conn)

sql="SELECT apart.sentence,Cpart.sentence, c.filename as filename,c.qno as qno,count(*)\
    FROM Ccut c, acut a,Apart,Cpart where substr(a.filename,2,4)=substr(c.filename,5,4) and a.cut=c.cut \
and c.filename=cpart.filename and apart.filename=a.filename \
group by c.filename,qno order by c.filename,count(*) DESC "
#sqlpart a 改格式 
sql="SELECT apart.sentence,Cpart.sentence, c.filename as filename,c.qno as qno,count(*) as score\
    FROM Ccut c, acut a,Apart,Cpart where substr(a.filename,5,4)=substr(c.filename,5,4) and a.cut=c.cut \
and c.filename=cpart.filename and apart.filename=a.filename  \
group by c.filename,qno order by c.filename,count(*) DESC "
# bpart type 1正向答案

sql="SELECT C.ID,c.qno as qno,count(*) as score \
    FROM Ccut c, acut a,bpart b where a.id=c.id and a.cut=c.cut and a.id=b.id \
 and b.Qtype=1 group by c.ID,qno order by c.ID,count(*) DESC "

#print(sql)
pdgrand=pd.read_sql(sql,conn)
oldID=0
for i in range(len(pdgrand)):
   ID=pdgrand.ID.values[i]
   qno=pdgrand.qno.values[i]
   score=pdgrand.score.values[i] 
   sql="update Cpart set score%d=%d where ID =%d " %(qno,score,ID)
      #print(sql)
   conn.execute(sql )
   #sql="update list_A set Answer=%d where substr(filename,5,4) ='%s' " %(qno,filename[5:4])
   if ID!=oldID:
      sql="update Cpart set Answer=%d where ID =%d " %(qno,ID)
      #print(sql)
      conn.execute(sql )
    #  sql="update list_A set Answer=%d where substr(filename,5,4) ='%s' " %(qno,filename[5:4])
      #print(sql)
      conn.execute(sql )
      #conn.commit()
   oldID=ID

#for bpart type2反向問題

conn.commit()

sql="SELECT C.ID,c.qno as qno,count(*) as score \
    FROM Ccut c, acut a,bpart b where a.id=c.id and a.cut=c.cut and a.id=b.id \
 and b.Qtype=2 group by c.ID,qno order by c.ID,count(*) DESC "


#print(sql)
pdgrand=pd.read_sql(sql,conn)
oldID=0
for i in range(len(pdgrand)):
   ID=pdgrand.ID.values[i]
   qno=pdgrand.qno.values[i]
   score=-pdgrand.score.values[i] 
   sql="update Cpart set score%d=%d where ID =%d " %(qno,score,ID)
      #print(sql)
   conn.execute(sql )
   #sql="update list_A set Answer=%d where substr(filename,5,4) ='%s' " %(qno,filename[5:4])
 
   if ID!=oldID:
      sql="update Cpart set Answer=%d where ID =%d " %(qno,ID)
      #print(sql)
      conn.execute(sql )
    #  sql="update list_A set Answer=%d where substr(filename,5,4) ='%s' " %(qno,filename[5:4])
      #print(sql)
      conn.execute(sql )
      #conn.commit()
   oldID=ID

#for bpart type2反向問題
conn.commit()
print('answer complete')
gencsv(conn)
print('generate CSV file')
genscore(conn)
print('generate score file')
conn.close()
# Out:
# 補完了
# init finish
# Qtype1 positive, qtype2 negative over
# answer complete
# 1500
# generate CSV file
# 1500
# generate score file

# %%
產生分數檔案
SELECT substr(filename,5,4) as ID, COALESCE( score1,0) as score1, COALESCE(score2,0) as score2, COALESCE(score3,0) as score3 , COALESCE(score4,0) as score4
FROM Cpart ;

# %%
 找沒答案的sql
    SELECT cast(substr(a.filename,5,4) as int) ,a.answer,b.filename,b.answer
FROM list_A a  left join cpart b  on substr(a.filename,5,4)=substr(b.filename,5,4) order by b.answer
